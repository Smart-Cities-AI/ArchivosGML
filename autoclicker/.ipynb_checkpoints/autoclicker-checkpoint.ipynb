# %%
import pyautogui
import PIL
import time
import random

# %%
delay_mid_actions = 0.1
randtime_interval = 0
left_corner = (110,150)
right_corner = (1850,900)
x_step = 40
y_step = 40
allowed_delay = 3
final_delay = 0.5

def closebox():
     while (time.monotonic() - start_time)<allowed_delay and not pyautogui.locateOnScreen('bad_click.png',grayscale=True, confidence=.8):
            if pyautogui.locateOnScreen('target3.png',grayscale=True, confidence=.8):
                temp = pyautogui.locateOnScreen('target3.png',grayscale=True, confidence=.8)
                time.sleep(random.uniform(delay_mid_actions -randtime_interval,delay_mid_actions +randtime_interval))
                pyautogui.click(temp[0]+(temp[2]/2),temp[1]+(temp[3]/2))
    
def downloadfile():
    print("Starting download")
    temp = pyautogui.locateOnScreen('target1.png',grayscale=True, confidence=.7)
    if not temp:
        return None
    time.sleep(random.uniform(delay_mid_actions -randtime_interval,delay_mid_actions +randtime_interval))
    pyautogui.click(temp[0]+(temp[2]/2),temp[1]+(temp[3]/2))
    print("Clicked the dropdown")
    temp = pyautogui.locateOnScreen('target2.png',grayscale=True, confidence=.5)
    if not temp:
        return None
    time.sleep(random.uniform(delay_mid_actions -randtime_interval,delay_mid_actions +randtime_interval))
    pyautogui.click(temp[0]+(temp[2]/2),temp[1]+(temp[3]/2))
    print("Clicked the file download")


for y in range(left_corner[1],right_corner[1],y_step):
    for x in range(left_corner[0],right_corner[0],x_step):
        pyautogui.click(x,y)
        print("Clicked on {0}, {1}".format(x,y))
        start_time = time.monotonic()
        while (time.monotonic() - start_time)<allowed_delay and not pyautogui.locateOnScreen('bad_click.png',grayscale=True, confidence=.8):
            if pyautogui.locateOnScreen('target1.png',grayscale=True, confidence=.8):
                print("Found the box, downloading!")
                downloadfile()
                print("Answer time: {0}s".format(time.monotonic()-start_time))
                break
        print("Closing the box")
        closebox()
        time.sleep(final_delay)
# Out:
# Clicked on 110, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.484000000054948s
# Closing the box
# Wait for X found
# Found!
# Clicked on 150, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.452999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 190, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.4849999999860302s
# Closing the box
# Wait for X found
# Found!
# Clicked on 230, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.7040000000270084s
# Closing the box
# Wait for X found
# Found!
# Clicked on 270, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5310000000754371s
# Closing the box
# Wait for X found
# Found!
# Clicked on 310, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5150000000139698s
# Closing the box
# Wait for X found
# Found!
# Clicked on 350, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3900000000139698s
# Closing the box
# Wait for X found
# Found!
# Clicked on 390, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3440000000409782s
# Closing the box
# Wait for X found
# Found!
# Clicked on 430, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.375s
# Closing the box
# Wait for X found
# Found!
# Clicked on 470, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.75s
# Closing the box
# Wait for X found
# Found!
# Clicked on 510, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.547000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 550, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.7349999999860302s
# Closing the box
# Wait for X found
# Found!
# Clicked on 590, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.75s
# Closing the box
# Wait for X found
# Found!
# Clicked on 630, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 670, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 710, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 750, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5s
# Closing the box
# Wait for X found
# Found!
# Clicked on 790, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.6559999999590218s
# Closing the box
# Wait for X found
# Found!
# Clicked on 830, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.547000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 870, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.062000000034459s
# Closing the box
# Wait for X found
# Found!
# Clicked on 910, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 950, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3589999999385327s
# Closing the box
# Wait for X found
# Found!
# Clicked on 990, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.702999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1030, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 1070, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 1110, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.702999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1150, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5310000000754371s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1190, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.547000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1230, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.375s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1270, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 1310, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.077999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1350, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.375s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1390, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.375s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1430, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 1470, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.702999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1510, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.702999999979511s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1550, 150
# Closing the box
# Wait for X found
# Found!
# Clicked on 1590, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.359000000054948s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1630, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.547000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1670, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3440000000409782s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1710, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.562000000034459s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1750, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5310000000754371s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1790, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5940000000409782s
# Closing the box
# Wait for X found
# Found!
# Clicked on 1830, 150
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.562000000034459s
# Closing the box
# Wait for X found
# Found!
# Clicked on 110, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3440000000409782s
# Closing the box
# Wait for X found
# Found!
# Clicked on 150, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.4839999999385327s
# Closing the box
# Wait for X found
# Found!
# Clicked on 190, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5s
# Closing the box
# Wait for X found
# Found!
# Clicked on 230, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5790000000270084s
# Closing the box
# Wait for X found
# Found!
# Clicked on 270, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.4059999999590218s
# Closing the box
# Wait for X found
# Found!
# Clicked on 310, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.297000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 350, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.3440000000409782s
# Closing the box
# Wait for X found
# Found!
# Clicked on 390, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.0619999999180436s
# Closing the box
# Wait for X found
# Found!
# Clicked on 430, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.062999999965541s
# Closing the box
# Wait for X found
# Found!
# Clicked on 470, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5309999999590218s
# Closing the box
# Wait for X found
# Found!
# Clicked on 510, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 2.172000000020489s
# Closing the box
# Wait for X found
# Found!
# Clicked on 550, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.5309999999590218s
# Closing the box
# Wait for X found
# Found!
# Clicked on 590, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.1099999999860302s
# Closing the box
# Wait for X found
# Found!
# Clicked on 630, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.7650000000139698s
# Closing the box
# Wait for X found
# Found!
# Clicked on 670, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 1.6099999999860302s
# Closing the box
# Wait for X found
# Found!
# Clicked on 710, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Clicked the file download
# Answer time: 2.125s
# Closing the box
# Wait for X found
# Found!
# Clicked on 750, 190
# Closing the box
# Wait for X found
# Found!
# Clicked on 790, 190
# Closing the box
# Wait for X found
# Found!
# Clicked on 830, 190
# Closing the box
# Wait for X found
# Found!
# Clicked on 870, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.062000000034459s
# Closing the box
# Wait for X found
# Found!
# Clicked on 910, 190
# Found the box, downloading!
# Starting download
# Clicked the dropdown
# Answer time: 1.125s
# Closing the box
# Wait for X found
